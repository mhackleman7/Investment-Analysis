# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('15stocks_price.csv')

# %%
df.head()
# Out:
#        date_gsheets   AAPL     KO   NFLX  BRK.B    DIS     IBM     VZ    WMT  \
# 0  01/03/2012 16:00  58.75  35.07  10.32  77.68  38.31  186.30  39.73  60.33
# 1  01/04/2012 16:00  59.06  34.85  11.49  76.80  38.85  185.54  39.21  59.71
# 2  01/05/2012 16:00  59.72  34.69  11.33  76.93  39.50  184.66  38.94  59.42
# 3  01/06/2012 16:00  60.34  34.47  12.33  76.39  39.91  182.54  38.33  59.00
# 4  01/09/2012 16:00  60.25  34.47  14.03  76.29  39.75  181.59  38.37  59.18
#
#       GE   TSLA     MA    AMZN   MSFT     UN      V
# 0  18.36  28.08  36.84  179.03  26.77  34.92  25.75
# 1  18.56  27.71  35.63  177.51  27.40  34.45  25.29
# 2  18.55  27.12  35.24  177.61  27.68  34.49  25.48
# 3  18.65  26.91  34.29  182.61  28.11  33.27  25.18
# 4  18.86  27.25  34.58  178.56  27.74  33.72  24.98

# %%
type(df['date_gsheets'][0])
# Out:
# str

# %%
df['date_gsheets'] = pd.to_datetime(df['date_gsheets'])

# %%
df['date_gsheets'].describe()
# Out:
# C:\Users\mhack\AppData\Local\Temp\ipykernel_17288\3129557638.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df['date_gsheets'].describe()
# count                    1509
# unique                   1509
# top       2012-01-03 16:00:00
# freq                        1
# first     2012-01-03 16:00:00
# last      2017-12-29 16:00:00
# Name: date_gsheets, dtype: object

# %%
df.describe()
# Out:
#               AAPL           KO         NFLX        BRK.B          DIS  \
# count  1509.000000  1509.000000  1509.000000  1509.000000  1509.000000
# mean    102.874380    41.119881    77.348801   130.578032    84.278529
# std      28.856614     2.915722    52.093716    29.738410    23.340639
# min      55.790000    33.490000     7.690000    76.290000    38.310000
# 25%      78.440000    38.900000    34.220000   112.700000    64.020000
# 50%      99.520000    41.170000    64.360000   134.140000    92.030000
# 75%     119.250000    43.000000   110.100000   146.690000   104.030000
# max     176.420000    47.430000   202.680000   199.560000   121.690000
#
#                IBM           VZ          WMT           GE         TSLA  \
# count  1509.000000  1509.000000  1509.000000  1509.000000  1509.000000
# mean    172.739881    47.687641    73.481365    25.564983   185.623453
# std      21.860902     3.686156     7.579578     3.725205    97.668462
# min     117.850000    36.800000    56.420000    17.360000    22.790000
# 25%     154.000000    45.560000    69.120000    23.190000   117.820000
# 50%     173.480000    48.120000    73.780000    25.790000   207.830000
# 75%     191.950000    50.030000    77.490000    28.630000   247.740000
# max     215.800000    56.530000    99.620000    32.930000   385.000000
#
#                 MA         AMZN         MSFT           UN            V
# count  1509.000000  1509.000000  1509.000000  1509.000000  1509.000000
# mean     83.008960   499.511928    46.459132    42.545036    63.079284
# std      28.046625   271.223704    14.872642     6.522422    22.482263
# min      33.910000   175.930000    26.370000    30.790000    24.780000
# 25%      58.930000   283.730000    33.030000    38.860000    45.040000
# 50%      84.590000   375.140000    44.400000    41.480000    64.950000
# 75%      97.890000   727.650000    55.700000    44.550000    79.010000
# max     154.190000  1195.830000    86.850000    61.390000   114.350000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_gsheets  1509 non-null   datetime64[ns]
#  1   AAPL          1509 non-null   float64
#  2   KO            1509 non-null   float64
#  3   NFLX          1509 non-null   float64
#  4   BRK.B         1509 non-null   float64
#  5   DIS           1509 non-null   float64
#  6   IBM           1509 non-null   float64
#  7   VZ            1509 non-null   float64
#  8   WMT           1509 non-null   float64
#  9   GE            1509 non-null   float64
#  10  TSLA          1509 non-null   float64
#  11  MA            1509 non-null   float64
#  12  AMZN          1509 non-null   float64
#  13  MSFT          1509 non-null   float64
#  14  UN            1509 non-null   float64
#  15  V             1509 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# memory usage: 188.8 KB

# %%
df.set_index('date_gsheets', inplace=True)

# %%
df.head()
# Out:
#                       AAPL     KO   NFLX  BRK.B    DIS     IBM     VZ    WMT  \
# date_gsheets
# 2012-01-03 16:00:00  58.75  35.07  10.32  77.68  38.31  186.30  39.73  60.33
# 2012-01-04 16:00:00  59.06  34.85  11.49  76.80  38.85  185.54  39.21  59.71
# 2012-01-05 16:00:00  59.72  34.69  11.33  76.93  39.50  184.66  38.94  59.42
# 2012-01-06 16:00:00  60.34  34.47  12.33  76.39  39.91  182.54  38.33  59.00
# 2012-01-09 16:00:00  60.25  34.47  14.03  76.29  39.75  181.59  38.37  59.18
#
#                         GE   TSLA     MA    AMZN   MSFT     UN      V
# date_gsheets
# 2012-01-03 16:00:00  18.36  28.08  36.84  179.03  26.77  34.92  25.75
# 2012-01-04 16:00:00  18.56  27.71  35.63  177.51  27.40  34.45  25.29
# 2012-01-05 16:00:00  18.55  27.12  35.24  177.61  27.68  34.49  25.48
# 2012-01-06 16:00:00  18.65  26.91  34.29  182.61  28.11  33.27  25.18
# 2012-01-09 16:00:00  18.86  27.25  34.58  178.56  27.74  33.72  24.98

# %%
returns_df = df.pct_change(1)

# %%
returns_df
# Out:
#                          AAPL        KO      NFLX     BRK.B       DIS  \
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00  0.005277 -0.006273  0.113372 -0.011329  0.014096
# 2012-01-05 16:00:00  0.011175 -0.004591 -0.013925  0.001693  0.016731
# 2012-01-06 16:00:00  0.010382 -0.006342  0.088261 -0.007019  0.010380
# 2012-01-09 16:00:00 -0.001492  0.000000  0.137875 -0.001309 -0.004009
# ...                       ...       ...       ...       ...       ...
# 2017-12-22 16:00:00  0.000000 -0.000219  0.006998 -0.004877 -0.008214
# 2017-12-26 16:00:00 -0.025370  0.004826 -0.011477 -0.001768 -0.005061
# 2017-12-27 16:00:00  0.000176  0.002620 -0.008095  0.005669 -0.004440
# 2017-12-28 16:00:00  0.002814 -0.004572  0.034740  0.004379  0.001208
# 2017-12-29 16:00:00 -0.010814  0.003500 -0.003892 -0.006715 -0.002413
#
#                           IBM        VZ       WMT        GE      TSLA  \
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00 -0.004079 -0.013088 -0.010277  0.010893 -0.013177
# 2012-01-05 16:00:00 -0.004743 -0.006886 -0.004857 -0.000539 -0.021292
# 2012-01-06 16:00:00 -0.011481 -0.015665 -0.007068  0.005391 -0.007743
# 2012-01-09 16:00:00 -0.005204  0.001044  0.003051  0.011260  0.012635
# ...                       ...       ...       ...       ...       ...
# 2017-12-22 16:00:00  0.006601  0.003396  0.001530  0.001717 -0.019478
# 2017-12-26 16:00:00  0.002164  0.000564  0.009673 -0.004000 -0.024323
# 2017-12-27 16:00:00  0.001963  0.001127  0.001008 -0.002869 -0.017807
# 2017-12-28 16:00:00  0.005943  0.002815  0.001410 -0.001151  0.011937
# 2017-12-29 16:00:00 -0.004025 -0.009358 -0.006539  0.005184 -0.012716
#
#                            MA      AMZN      MSFT        UN         V
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00 -0.032845 -0.008490  0.023534 -0.013459 -0.017864
# 2012-01-05 16:00:00 -0.010946  0.000563  0.010219  0.001161  0.007513
# 2012-01-06 16:00:00 -0.026958  0.028152  0.015535 -0.035373 -0.011774
# 2012-01-09 16:00:00  0.008457 -0.022178 -0.013163  0.013526 -0.007943
# ...                       ...       ...       ...       ...       ...
# 2017-12-22 16:00:00  0.002126 -0.005448  0.000117  0.001599  0.002491
# 2017-12-26 16:00:00  0.002851  0.007190 -0.001286  0.002661  0.002662
# 2017-12-27 16:00:00  0.000793  0.004674  0.003630 -0.001415  0.009116
# 2017-12-28 16:00:00  0.002444  0.003248  0.000117 -0.001063  0.002894
# 2017-12-29 16:00:00 -0.002701 -0.014021 -0.002100 -0.001241 -0.002886
#
# [1509 rows x 15 columns]

# %%
num_stocks = 15
weights = [1 / num_stocks] * num_stocks

# %%
weights
# Out:
# [0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667,
#  0.06666666666666667]

# %%
vcv_matrix = returns_df.cov()

# %%
vcv_matrix
# Out:
#            AAPL        KO      NFLX     BRK.B       DIS       IBM        VZ  \
# AAPL   0.000246  0.000028  0.000059  0.000044  0.000048  0.000048  0.000027
# KO     0.000028  0.000075  0.000026  0.000037  0.000037  0.000032  0.000033
# NFLX   0.000059  0.000026  0.001063  0.000054  0.000057  0.000046  0.000015
# BRK.B  0.000044  0.000037  0.000054  0.000080  0.000055  0.000050  0.000038
# DIS    0.000048  0.000037  0.000057  0.000055  0.000132  0.000045  0.000039
# IBM    0.000048  0.000032  0.000046  0.000050  0.000045  0.000132  0.000035
# VZ     0.000027  0.000033  0.000015  0.000038  0.000039  0.000035  0.000103
# WMT    0.000029  0.000029  0.000035  0.000032  0.000034  0.000028  0.000032
# GE     0.000047  0.000035  0.000060  0.000057  0.000058  0.000057  0.000044
# TSLA   0.000094  0.000038  0.000230  0.000060  0.000080  0.000065  0.000034
# MA     0.000070  0.000040  0.000106  0.000061  0.000063  0.000057  0.000036
# AMZN   0.000075  0.000038  0.000179  0.000054  0.000066  0.000050  0.000032
# MSFT   0.000072  0.000039  0.000096  0.000053  0.000056  0.000062  0.000042
# UN     0.000048  0.000042  0.000059  0.000045  0.000045  0.000042  0.000038
# V      0.000060  0.000037  0.000090  0.000057  0.000060  0.000052  0.000035
#
#             WMT        GE      TSLA        MA      AMZN      MSFT        UN  \
# AAPL   0.000029  0.000047  0.000094  0.000070  0.000075  0.000072  0.000048
# KO     0.000029  0.000035  0.000038  0.000040  0.000038  0.000039  0.000042
# NFLX   0.000035  0.000060  0.000230  0.000106  0.000179  0.000096  0.000059
# BRK.B  0.000032  0.000057  0.000060  0.000061  0.000054  0.000053  0.000045
# DIS    0.000034  0.000058  0.000080  0.000063  0.000066  0.000056  0.000045
# IBM    0.000028  0.000057  0.000065  0.000057  0.000050  0.000062  0.000042
# VZ     0.000032  0.000044  0.000034  0.000036  0.000032  0.000042  0.000038
# WMT    0.000115  0.000030  0.000036  0.000034  0.000028  0.000034  0.000030
# GE     0.000030  0.000136  0.000066  0.000060  0.000057  0.000055  0.000046
# TSLA   0.000036  0.000066  0.000931  0.000107  0.000147  0.000090  0.000066
# MA     0.000034  0.000060  0.000107  0.000165  0.000106  0.000077  0.000058
# AMZN   0.000028  0.000057  0.000147  0.000106  0.000346  0.000097  0.000052
# MSFT   0.000034  0.000055  0.000090  0.000077  0.000097  0.000195  0.000053
# UN     0.000030  0.000046  0.000066  0.000058  0.000052  0.000053  0.000144
# V      0.000034  0.000056  0.000088  0.000127  0.000095  0.000072  0.000053
#
#               V
# AAPL   0.000060
# KO     0.000037
# NFLX   0.000090
# BRK.B  0.000057
# DIS    0.000060
# IBM    0.000052
# VZ     0.000035
# WMT    0.000034
# GE     0.000056
# TSLA   0.000088
# MA     0.000127
# AMZN   0.000095
# MSFT   0.000072
# UN     0.000053
# V      0.000163

# %%
var_p = np.dot(np.transpose(weights), np.dot(vcv_matrix, weights))

# %%
var_p
# Out:
# 7.065601793193966e-05

# %%
sd_p = np.sqrt(var_p)

# %%
sd_p
# Out:
# 0.008405713410052692

# %%
sd_p_annual = sd_p * np.sqrt(250)

# %%
sd_p_annual
# Out:
# 0.13290599867193698

# %%
individual_risks = np.std(returns_df) * np.sqrt(250)

# %%
individual_risks
# Out:
# AAPL     0.248003
# KO       0.137257
# NFLX     0.515302
# BRK.B    0.141030
# DIS      0.181313
# IBM      0.181705
# VZ       0.160220
# WMT      0.169281
# GE       0.184478
# TSLA     0.482230
# MA       0.203333
# AMZN     0.293943
# MSFT     0.220560
# UN       0.189686
# V        0.201850
# dtype: float64

# %%
returns_df.head()
# Out:
#                          AAPL        KO      NFLX     BRK.B       DIS  \
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00  0.005277 -0.006273  0.113372 -0.011329  0.014096
# 2012-01-05 16:00:00  0.011175 -0.004591 -0.013925  0.001693  0.016731
# 2012-01-06 16:00:00  0.010382 -0.006342  0.088261 -0.007019  0.010380
# 2012-01-09 16:00:00 -0.001492  0.000000  0.137875 -0.001309 -0.004009
#
#                           IBM        VZ       WMT        GE      TSLA  \
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00 -0.004079 -0.013088 -0.010277  0.010893 -0.013177
# 2012-01-05 16:00:00 -0.004743 -0.006886 -0.004857 -0.000539 -0.021292
# 2012-01-06 16:00:00 -0.011481 -0.015665 -0.007068  0.005391 -0.007743
# 2012-01-09 16:00:00 -0.005204  0.001044  0.003051  0.011260  0.012635
#
#                            MA      AMZN      MSFT        UN         V
# date_gsheets
# 2012-01-03 16:00:00       NaN       NaN       NaN       NaN       NaN
# 2012-01-04 16:00:00 -0.032845 -0.008490  0.023534 -0.013459 -0.017864
# 2012-01-05 16:00:00 -0.010946  0.000563  0.010219  0.001161  0.007513
# 2012-01-06 16:00:00 -0.026958  0.028152  0.015535 -0.035373 -0.011774
# 2012-01-09 16:00:00  0.008457 -0.022178 -0.013163  0.013526 -0.007943

# %%
tickers = list(returns_df.columns)

# %%
tickers
# Out:
# ['AAPL',
#  'KO',
#  'NFLX',
#  'BRK.B',
#  'DIS',
#  'IBM',
#  'VZ',
#  'WMT',
#  'GE',
#  'TSLA',
#  'MA',
#  'AMZN',
#  'MSFT',
#  'UN',
#  'V']

# %%
portfolios = []

for i in range(1, len(tickers) + 1):
    portfolios.append(tickers[0:i])

# %%
portfolios
# Out:
# [['AAPL'],
#  ['AAPL', 'KO'],
#  ['AAPL', 'KO', 'NFLX'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS', 'IBM'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS', 'IBM', 'VZ'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS', 'IBM', 'VZ', 'WMT'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS', 'IBM', 'VZ', 'WMT', 'GE'],
#  ['AAPL', 'KO', 'NFLX', 'BRK.B', 'DIS', 'IBM', 'VZ', 'WMT', 'GE', 'TSLA'],
#  ['AAPL',
#   'KO',
#   'NFLX',
#   'BRK.B',
#   'DIS',
#   'IBM',
#   'VZ',
#   'WMT',
#   'GE',
#   'TSLA',
#   'MA'],
#  ['AAPL',
#   'KO',
#   'NFLX',
#   'BRK.B',
#   'DIS',
#   'IBM',
#   'VZ',
#   'WMT',
#   'GE',
#   'TSLA',
#   'MA',
#   'AMZN'],
#  ['AAPL',
#   'KO',
#   'NFLX',
#   'BRK.B',
#   'DIS',
#   'IBM',
#   'VZ',
#   'WMT',
#   'GE',
#   'TSLA',
#   'MA',
#   'AMZN',
#   'MSFT'],
#  ['AAPL',
#   'KO',
#   'NFLX',
#   'BRK.B',
#   'DIS',
#   'IBM',
#   'VZ',
#   'WMT',
#   'GE',
#   'TSLA',
#   'MA',
#   'AMZN',
#   'MSFT',
#   'UN'],
#  ['AAPL',
#   'KO',
#   'NFLX',
#   'BRK.B',
#   'DIS',
#   'IBM',
#   'VZ',
#   'WMT',
#   'GE',
#   'TSLA',
#   'MA',
#   'AMZN',
#   'MSFT',
#   'UN',
#   'V']]

# %%
# Calculate the risk of each portfolio
portfolio_risks = []

for port in portfolios:
    df = returns_df[port]
    
    num_stocks = len(df.columns)
    weights = [1 / num_stocks] * num_stocks
    vcv_p = df.cov()
    
    var_p = np.dot(np.transpose(weights), np.dot(vcv_p, weights))
    sd_p = np.sqrt(var_p)
    sd_p_annual = sd_p * np.sqrt(250)
    
    portfolio_risks.append(sd_p_annual)

# %%
portfolio_risks
# Out:
# [0.24808505375568835,
#  0.1536167740652437,
#  0.21145655417390294,
#  0.17491660730394223,
#  0.15759159863421662,
#  0.14571266561387228,
#  0.13422929292622485,
#  0.1262813443034354,
#  0.12416648815658816,
#  0.13539455221149158,
#  0.13459130123519153,
#  0.13677678703598517,
#  0.1360407362019938,
#  0.13317149143227183,
#  0.13290599867193698]

# %%
risks_df = pd.DataFrame(portfolio_risks)

# %%
risks_df.rename(columns={risks_df.columns[0] : 'total_risk'}, inplace=True)

# %%
risks_df
# Out:
#     total_risk
# 0     0.248085
# 1     0.153617
# 2     0.211457
# 3     0.174917
# 4     0.157592
# 5     0.145713
# 6     0.134229
# 7     0.126281
# 8     0.124166
# 9     0.135395
# 10    0.134591
# 11    0.136777
# 12    0.136041
# 13    0.133171
# 14    0.132906

# %%
risks_df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
np.std(returns_df) * np.sqrt(250)
# Out:
# AAPL     0.248003
# KO       0.137257
# NFLX     0.515302
# BRK.B    0.141030
# DIS      0.181313
# IBM      0.181705
# VZ       0.160220
# WMT      0.169281
# GE       0.184478
# TSLA     0.482230
# MA       0.203333
# AMZN     0.293943
# MSFT     0.220560
# UN       0.189686
# V        0.201850
# dtype: float64

# %%
risks_df
# Out:
#     total_risk
# 0     0.248085
# 1     0.153617
# 2     0.211457
# 3     0.174917
# 4     0.157592
# 5     0.145713
# 6     0.134229
# 7     0.126281
# 8     0.124166
# 9     0.135395
# 10    0.134591
# 11    0.136777
# 12    0.136041
# 13    0.133171
# 14    0.132906
